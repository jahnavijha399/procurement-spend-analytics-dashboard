# %%
import pandas as pd

# %%
df=pd.read_csv("procurement_raw.csv")
df.head()
# Out:
#   Invoice_ID Vendor_Name         Category  Department Invoice_Date  Amount  \
# 0       INV1   Microsoft        Logistics          IT   2025-12-23   15425
# 1       INV2          HP        Logistics   Marketing   2024-07-26   10544
# 2       INV3       Cisco         Software  Operations   2025-08-29     982
# 3       INV4      Lenovo      IT Hardware   Marketing   2026-01-17   10308
# 4       INV5         TCS  Office Supplies  Operations   2025-09-24   22520
#
#   Payment_status Region
# 0        Pending  South
# 1        Pending   East
# 2        Pending   West
# 3        Pending   East
# 4           Paid  South

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice_ID      10000 non-null  object
#  1   Vendor_Name     10000 non-null  object
#  2   Category        10000 non-null  object
#  3   Department      10000 non-null  object
#  4   Invoice_Date    10000 non-null  object
#  5   Amount          10000 non-null  int64
#  6   Payment_status  10000 non-null  object
#  7   Region          10000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
df.isnull().sum()
# Out:
# Invoice_ID        0
# Vendor_Name       0
# Category          0
# Department        0
# Invoice_Date      0
# Amount            0
# Payment_status    0
# Region            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['Invoice_Date'] = pd.to_datetime(df['Invoice_Date'])

# %%
df['Month'] = df['Invoice_Date'].dt.month

# %%
df.to_csv("procurement_clean.csv", index=False)
